# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Ecuación de Difusión
# [Enlace a Libreta] (http://nbviewer.ipython.org/github/htapia/lania-pd/blob/master/01_Libreta02_EcuacionDeDifusion.ipynb)
#
# ## Objetivo:
# 1. Implementar la solución numérica a la discretización de la ecuación de difusión en 2D utilizando Python
#
# ## Metodologia
# Presentamos la implementación del código serial en el CPU utilizando el lenguaje de programación Python, por medio de interacciones directas con la libreta (es decir todo se desarrolla por medio de esta plataforma, haciendo uso del sistema operativo por medio de llamadas a través de funciones que proporciona IPython Notebook). Se caracteriza el tiempo de ejecución por medio de funciones nativas a C (implementadas en el código) y por medio de la función `timeit` propia de Python. Se omite la descripción del código fuente de C pero se proporciona al final de la libreta.

# %% [markdown]
# ### Codigo en Python
# En las siguientes lineas implementamos la solución al mismo problema que tratamos usando el programa `difusionCPU` pero usando Python. Comenzamos por definir los valores de las mismas variables que en listado de C y después iteramos sobre el numero de pasos, tambien fijado en 40000.

# %%
nx = 512
ny = 512

alpha = 0.645
dx = 3.5/(nx-1)
dy = 3.5/(ny-1)
sigma = 0.25
dt = 0.00001
time = 0.4
steps = np.int(np.ceil(time/dt))

# %% [markdown]
# Medimos el tiempo de ejecución usando la función `timeit` de Python:

# %%
# %%timeit
u = np.zeros((ny,nx))
for n in range(steps):
    un = u.copy()
    u[1:-1,1:-1]=un[1:-1,1:-1]+alpha*dt/dx**2*(un[2:,1:-1]-2*un[1:-1,1:-1]+un[0:-2,1:-1])+alpha*dt/dy**2*(un[1:-1,2:]-2*un[1:-1,1:-1]+un[1:-1,0:-2])
    u[0,:]=200
    u[-1,:]=0
    u[:,0]=200
    u[:,-1]=0
# Out:
# 1 loops, best of 3: 2min 17s per loop

# %% [markdown]
# El tiempo de ejecución en Python es del mismo orden que el tiempo de ejecución del código en C. Si el tamaño de la malla es mayor que 512x512 el problema en Python puede tardar un tiempo considerable.
#
# En general el lenguaje de programación C es mucho mas rápido ya que el código que se ejecuta es compilado mientras que Python es interpretado.
#
# Finalmente graficamos la distribución de temperatura de los resultados de Python.

# %%
x = np.linspace(0,3.5,nx)
y = np.linspace(0,3.5,ny)

X,Y = np.meshgrid(x,y)
plt.pcolormesh(X,Y,u[:], cmap=cm.gnuplot)
plt.axes().set_aspect('equal', 'box')

# %% [markdown]
# ##Ejercicios
#
# 1. Realizar varias mediciones de tiempo de ejecución del programa serial de Python para distintos tamaños de la malla.

# %% [markdown]
# ##Material adicional
# Presentamos a continuación el listado completo en Python y como comparación el listado del código C.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

nx = 512
ny = 512

alpha = 0.645
dx = 3.5/(nx-1)
dy = 3.5/(ny-1)
sigma = 0.25
dt = 0.00001
time = 0.4
steps = np.int(np.ceil(time/dt))
# %%timeit
u = np.zeros((ny,nx))
for n in range(steps):
    un = u.copy()
    u[1:-1,1:-1]=un[1:-1,1:-1]+alpha*dt/dx**2*(un[2:,1:-1]-2*un[1:-1,1:-1]+un[0:-2,1:-1])+alpha*dt/dy**2*(un[1:-1,2:]-2*un[1:-1,1:-1]+un[1:-1,0:-2])
    u[0,:]=200
    u[-1,:]=0
    u[:,0]=200
    u[:,-1]=0
    
x = np.linspace(0,3.5,nx)
y = np.linspace(0,3.5,ny)

X,Y = np.meshgrid(x,y)
plt.pcolormesh(X,Y,u[:], cmap=cm.gnuplot)
plt.axes().set_aspect('equal', 'box')

# %%
# %load ../codes/difusionCPU.cu

# %%
// Codigo serial para resolver la ecuacion de difusion en 2D //
#include <iostream>
#include <fstream>
#include <cmath>
#include <stdio.h>
#include <sys/time.h>

double get_time() 
{  struct timeval tim;
  gettimeofday(&tim, NULL);
  return (double) tim.tv_sec+(tim.tv_usec/1000000.0);
}


void update (float *u, float *u_prev, int N, float h, float dt, float alpha)
{
	int I;
	for (int j=0; j<N; j++)
	{	for (int i=0; i<N; i++)
		{	I = j*N+i;
			u_prev[I] = u[I];
		}
	}

	for (int j=1; j<N-1; j++)
	{	for (int i=1; i<N-1; i++)
		{	I = j*N+i;
			u[I] = u_prev[I] + alpha*dt/(h*h) * (u_prev[I+1] + u_prev[I-1] + u_prev[I+N] + u_prev[I-N] - 4*u_prev[I]);
		}
	}
	
	// Boundary conditions are automatically imposed
	// as we don't touch boundaries
}

int main(int argc, char**argv)
{
	int N;
    if(argc == 1) {
        N = 512;
    } else if(argc == 2) {
        N = atoi(argv[1]);
    } else {
        printf("\n    Parametros no validos!"
           "\n    Uso: ./difusionCPU               # malla"
           "\n    Uso: ./difusionCPU <N>           # malla"
           "\n");
        exit(0);
    }
	// Allocate in CPU
    //	int N = 512;

	float xmin 	= 0.0f;
	float xmax 	= 3.5f;
	float ymin 	= 0.0f;
	//float ymax 	= 2.0f;
	float h   	= (xmax-xmin)/(N-1);
	float dt	= 0.00001f;	
	float alpha	= 0.645f;
	float time 	= 0.4f;

	int steps = ceil(time/dt);
	int I;

	float *x  	= new float[N*N]; 
	float *y  	= new float[N*N]; 
	float *u  	= new float[N*N];
	float *u_prev  	= new float[N*N];

    std::cout<<"N = "<<N<<std::endl;
    
	// Generate mesh and intial condition
	for (int j=0; j<N; j++)
	{	for (int i=0; i<N; i++)
		{	I = N*j + i;
			x[I] = xmin + h*i;
			y[I] = ymin + h*j;
			u[I] = 0.0f;
			if ( (i==0) || (j==0)) 
				{u[I] = 200.0f;}
		}
	}

	// Loop 
	double start = get_time();
	for (int t=0; t<steps; t++)
	{	update (u, u_prev, N, h, dt, alpha);
	}
	double stop = get_time();
	
	double elapsed = stop - start;
	std::cout<<"time = "<<elapsed<<std::endl;

	std::ofstream temperature("temperature_cpu.txt");
	for (int j=0; j<N; j++)
	{	for (int i=0; i<N; i++)
		{	I = N*j + i;
		//	std::cout<<u[I]<<"\t";
			temperature<<x[I]<<"\t"<<y[I]<<"\t"<<u[I]<<std::endl;
		}
		temperature<<"\n";
		//std::cout<<std::endl;
	}

	temperature.close();
}
